# %%
datoteka = './bodovanje_poravnanja/bodovanjeViterbi214-0.001.txt'

bodovanje_viterbi214_001 = []

with open(datoteka, 'r') as f:
    for redak in f:
        bodovanje_viterbi214_001.append(int(redak.strip()))


print(bodovanje_viterbi214_001)
# Out:
# [12334, 14544, 14868, 14616, 14800, 14170, 13307, 14523, 14457, 13817, 14649, 12063, 13643, 14678, 15207, 14439, 14696, 14252, 14775, 14065, 14416, 12124, 14420, 14476, 14458, 14767, 12067, 14361, 14641, 11433, 14025, 14810, 11862, 12168, 12049, 11924, 14189, 13381, 11901, 12031, 14082, 11556, 14775, 11947, 11888, 15219, 13806, 13991, 15453, 11725]

# %%
datoteka = './bodovanje_poravnanja/bodovanjeViterbi214-0,01-100.txt'

bodovanje_viterbi214_01 = []

with open(datoteka, 'r') as f:
    for redak in f:
        bodovanje_viterbi214_01.append(int(redak.strip()))


print(bodovanje_viterbi214_01)
# Out:
# [12196, 14720, 14671, 14554, 14858, 13975, 13264, 14360, 14133, 13786, 14477, 11788, 13489, 14548, 15053, 14137, 14727, 14085, 14844, 13753, 13929, 11957, 14449, 14378, 14371, 14785, 11938, 14248, 14713, 11349, 13825, 14884, 11369, 12248, 12192, 11554, 14255, 13302, 11788, 12065, 14100, 11385, 14717, 11901, 11865, 15172, 13839, 14046, 15255, 11573]

# %%
datoteka = './bodovanje_poravnanja/bodovanjeViterbi212-0,01-100.txt'

bodovanje_viterbi212_01 = []

with open(datoteka, 'r') as f:
    for redak in f:
        bodovanje_viterbi212_01.append(int(redak.strip()))


print(bodovanje_viterbi212_01)
# Out:
# [13498, 15130, 15153, 15136, 15412, 14695, 14198, 14830, 14747, 14512, 14975, 13544, 14445, 15070, 15453, 14715, 15217, 14839, 15292, 14575, 14711, 13743, 14987, 14874, 14949, 15265, 13300, 14860, 15191, 13341, 14547, 15190, 13415, 13548, 13546, 13062, 14783, 14220, 13198, 13877, 14736, 13377, 15335, 13319, 13743, 15514, 14533, 14652, 15605, 13539]

# %%
datoteka = './bodovanje_poravnanja/bodovanjeViterbi212-0.001-100.txt'

bodovanje_viterbi212_001 = []

with open(datoteka, 'r') as f:
    for redak in f:
        bodovanje_viterbi212_001.append(int(redak.strip()))


print(bodovanje_viterbi212_001)
# Out:
# [13588, 15022, 15282, 15166, 15382, 14842, 14225, 14941, 14963, 14551, 15071, 13727, 14535, 15160, 15555, 14889, 15202, 14950, 15259, 14767, 14990, 13842, 14990, 14940, 15024, 15259, 13381, 14953, 15155, 13389, 14679, 15148, 13724, 13512, 13471, 13284, 14753, 14271, 13291, 13859, 14730, 13488, 15377, 13337, 13770, 15553, 14536, 14625, 15731, 13623]

# %%
datoteka = './bodovanje_poravnanja/bodovanjeNW212.txt'

bodovanje_NW212 = []

with open(datoteka, 'r') as f:
    for redak in f:
        bodovanje_NW212.append(int(redak.strip()))


print(bodovanje_NW212)
# Out:
# [14044, 15421, 15597, 15694, 15928, 15415, 15002, 15418, 15410, 15235, 15557, 14063, 15297, 15676, 15888, 15324, 15640, 15547, 15751, 15379, 15566, 14367, 15533, 15390, 15582, 15811, 13903, 15568, 15668, 13971, 15303, 15436, 14264, 14043, 14008, 13854, 15281, 15006, 13858, 14309, 15423, 14148, 15872, 13973, 14292, 15835, 15103, 15315, 15920, 14157]

# %%
datoteka = './bodovanje_poravnanja/bodovanjeNW214.txt'

bodovanje_NW214 = []

with open(datoteka, 'r') as f:
    for redak in f:
        bodovanje_NW214.append(int(redak.strip()))


print(bodovanje_NW214)
# Out:
# [13023, 15091, 15277, 15404, 15713, 15007, 14570, 15250, 15145, 14860, 15346, 12529, 14860, 15485, 15758, 14982, 15331, 15133, 15542, 15024, 15286, 12876, 15284, 15167, 15327, 15643, 12796, 15299, 15467, 12297, 14924, 15233, 12640, 12967, 12863, 12771, 14948, 14528, 12748, 12684, 15161, 12553, 15611, 12901, 12700, 15648, 14718, 15082, 15722, 12506]

# %%
import numpy as np
import pandas as pd
# računanje srednje vrijednosti i standardne devijacije
srednja_vrijednost_212_01 = np.mean(bodovanje_viterbi212_01)
std_dev_212_01 = np.std(bodovanje_viterbi212_01)

srednja_vrijednost_212_001 = np.mean(bodovanje_viterbi212_001)
std_dev_212_001 = np.std(bodovanje_viterbi212_001)

srednja_vrijednost_212_NW = np.mean(bodovanje_NW212)
std_dev_212_NW = np.std(bodovanje_NW212)

srednja_vrijednost_214_01 = np.mean(bodovanje_viterbi214_01)
std_dev_214_01 = np.std(bodovanje_viterbi214_01)

srednja_vrijednost_214_001 = np.mean(bodovanje_viterbi214_001)
std_dev_214_001 = np.std(bodovanje_viterbi214_001)

srednja_vrijednost_214_NW = np.mean(bodovanje_NW214)
std_dev_214_NW = np.std(bodovanje_NW214)



podaci = {
    'Model': ['bodovanje_viterbi212_01', 'bodovanje_viterbi212_001', 'bodovanje_NW212', 'bodovanje_viterbi214_01', 'bodovanje_viterbi214_001', 'bodovanje_NW214'],
    'Srednja Vrijednost': [srednja_vrijednost_212_01, srednja_vrijednost_212_001, srednja_vrijednost_212_NW,srednja_vrijednost_214_01, srednja_vrijednost_214_001, srednja_vrijednost_214_NW],
    'Standardna Devijacija': [std_dev_212_01, std_dev_212_001, std_dev_212_NW, std_dev_214_01, std_dev_214_001, std_dev_214_NW]
}

df = pd.DataFrame(podaci)


df
# Out:
#                       Model  Srednja Vrijednost  Standardna Devijacija
# 0   bodovanje_viterbi212_01            14487.92             737.178075
# 1  bodovanje_viterbi212_001            14555.24             722.950719
# 2           bodovanje_NW212            15080.90             689.120955
# 3   bodovanje_viterbi214_01            13577.40            1238.996190
# 4  bodovanje_viterbi214_001            13676.96            1211.966121
# 5           bodovanje_NW214            14473.60            1179.472391

# %%
poravnanja = {"NW 214": bodovanje_NW214, "Viterbi - 0.001 - 214": bodovanje_viterbi214_001, "Viterbi - 0.01 - 214":bodovanje_viterbi214_01 }
df214 = pd.DataFrame(poravnanja)
df214["Viterbi-0.001/NW"] = df214["Viterbi - 0.001 - 214"]/df214["NW 214"]
df214["Viterbi-0.01/NW"] = df214["Viterbi - 0.01 - 214"]/df214["NW 214"]
df214["Viterbi-0.001/Viterbi-0.01"] = df214["Viterbi - 0.001 - 214"]/df214["Viterbi - 0.01 - 214"]
df214
# Out:
#     NW 214  Viterbi - 0.001 - 214  Viterbi - 0.01 - 214  Viterbi-0.001/NW  \
# 0    13023                  12334                 12196          0.947094
# 1    15091                  14544                 14720          0.963753
# 2    15277                  14868                 14671          0.973228
# 3    15404                  14616                 14554          0.948844
# 4    15713                  14800                 14858          0.941895
# 5    15007                  14170                 13975          0.944226
# 6    14570                  13307                 13264          0.913315
# 7    15250                  14523                 14360          0.952328
# 8    15145                  14457                 14133          0.954572
# 9    14860                  13817                 13786          0.929812
# 10   15346                  14649                 14477          0.954581
# 11   12529                  12063                 11788          0.962806
# ...

# %%
df214["Viterbi-0.001/Viterbi-0.01"].describe()#skoro isto
# Out:
# count    50.000000
# mean      1.007654
# std       0.011457
# min       0.988043
# 25%       0.998176
# 50%       1.007109
# 75%       1.013095
# max       1.043364
# Name: Viterbi-0.001/Viterbi-0.01, dtype: float64

# %%
df214["Viterbi-0.001/NW"].describe() #Min-91,max 98
# Out:
# count    50.000000
# mean      0.944492
# std       0.014860
# min       0.913315
# 25%       0.936306
# 50%       0.943194
# 75%       0.951908
# max       0.982890
# Name: Viterbi-0.001/NW, dtype: float64

# %%
df214["Viterbi-0.01/NW"].describe()#Min-89,Max-97
# Out:
# count    50.000000
# mean      0.937435
# std       0.018140
# min       0.899446
# 25%       0.926702
# 50%       0.938558
# 75%       0.947273
# max       0.977089
# Name: Viterbi-0.01/NW, dtype: float64

# %%
poravnanja = {"NW 212": bodovanje_NW212, "Viterbi - 0.001 - 212": bodovanje_viterbi212_001, "Viterbi - 0.01 - 212":bodovanje_viterbi212_01 }
df212 = pd.DataFrame(poravnanja)
df212["Viterbi-0.001/NW"] = df212["Viterbi - 0.001 - 212"]/df212["NW 212"]
df212["Viterbi-0.01/NW"] = df212["Viterbi - 0.01 - 212"]/df212["NW 212"]
df212["Viterbi-0.001/Viterbi-0.01"] = df212["Viterbi - 0.001 - 212"]/df212["Viterbi - 0.01 - 212"]
df212
# Out:
#     NW 212  Viterbi - 0.001 - 212  Viterbi - 0.01 - 212  Viterbi-0.001/NW  \
# 0    14044                  13588                 13498          0.967531
# 1    15421                  15022                 15130          0.974126
# 2    15597                  15282                 15153          0.979804
# 3    15694                  15166                 15136          0.966357
# 4    15928                  15382                 15412          0.965721
# 5    15415                  14842                 14695          0.962828
# 6    15002                  14225                 14198          0.948207
# 7    15418                  14941                 14830          0.969062
# 8    15410                  14963                 14747          0.970993
# 9    15235                  14551                 14512          0.955103
# 10   15557                  15071                 14975          0.968760
# 11   14063                  13727                 13544          0.976108
# ...

# %%
df212["Viterbi-0.001/Viterbi-0.01"].describe()#skoro isto
# Out:
# count    50.000000
# mean      1.004728
# std       0.006257
# min       0.992862
# 25%       0.999755
# 50%       1.004727
# 75%       1.007484
# max       1.023034
# Name: Viterbi-0.001/Viterbi-0.01, dtype: float64

# %%
df212["Viterbi-0.01/NW"].describe()#Min-94%,max-98%
# Out:
# count    50.000000
# mean      0.960493
# std       0.010347
# min       0.940480
# 25%       0.953584
# 50%       0.961232
# 75%       0.966882
# max       0.984063
# Name: Viterbi-0.01/NW, dtype: float64

# %%
df212["Viterbi-0.001/NW"].describe()#Min-95,max-98
# Out:
# count    50.000000
# mean      0.964998
# std       0.008428
# min       0.948207
# 25%       0.960278
# 50%       0.963833
# 75%       0.968801
# max       0.988128
# Name: Viterbi-0.001/NW, dtype: float64

# %%
import matplotlib.pyplot as plt
import os


boje = ['coral', 'lightblue', 'gray']

plt.figure(figsize=(12, 6))
x_os = range(1, len(bodovanje_viterbi212_01) + 1)


plt.plot(x_os, bodovanje_viterbi212_01, label='viterbi_delta=0.01', color=boje[0])
plt.plot(x_os, bodovanje_viterbi212_001, label='viterbi_delta=0.001', color=boje[1])
plt.plot(x_os, bodovanje_NW212, label='NW', color=boje[2])


plt.title('Bodovanje poravnanja - prva shema bodovanja (+2,-1,-2)')
plt.xlabel('Redni broj para sljedova')
plt.ylabel('Vrijednost')


plt.legend()

plt.savefig(os.path.join("./bodovanje_poravnanja/", "bodovanje_graf1.png"));

# %%
boje = ['coral', 'lightblue', 'gray']

plt.figure(figsize=(12, 6))
x_os = range(1, len(bodovanje_viterbi212_01) + 1)


plt.plot(x_os, bodovanje_viterbi214_01, label='viterbi_delta=0.01', color=boje[0])
plt.plot(x_os, bodovanje_viterbi214_001, label='viterbi_delta=0.001', color=boje[1])
plt.plot(x_os, bodovanje_NW214, label='NW', color=boje[2])


plt.title('Bodovanje poravnanja - druga shema bodovanja (+2,-1,-4)')
plt.xlabel('Redni broj para sljedova')
plt.ylabel('Vrijednost')


plt.legend()


plt.savefig(os.path.join("./bodovanje_poravnanja/", "bodovanje_graf2.png"));
